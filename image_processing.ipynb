# %%
import numpy as np
import pandas as pd
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading an image

# %%
img = mpimg.imread('data/shrek.png') 
img.shape
# Out:
# (748, 1188, 4)

# %%
plt.imshow(img)

# %% [markdown]
# # Cleaning an image

# %% [markdown]
# # Loading a model

# %% [markdown]
# # Running a model
